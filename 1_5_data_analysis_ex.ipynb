# %% [markdown]
# <a href="https://colab.research.google.com/github/minyoung347/python101/blob/main/1_5_data_analysis_ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get -y install fonts-nanum
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (18.9 MB/s)
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 121913 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
# 필요 라이브러리 불러오기
import matplotlib.font_manager as fm
import os
import matplotlib.pyplot as plt

# apt-get : 패키지 설치 명령어
# -qq : 에러외의 메세지 숨기는 옵션키
# !apt-get -qq install fonts-nanum


fe = fm.FontEntry(
    fname=r'/usr/share/fonts/truetype/nanum/NanumGothic.ttf', # ttf 파일이 저장되어 있는 경로
    name='NanumGothic')                        # 이 폰트의 원하는 이름 설정
fm.fontManager.ttflist.insert(0, fe)              # Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 18, 'font.family': 'NanumGothic'}) # 폰트 설정

# 테스트 해보기
fig, ax = plt.subplots(1, 1, figsize=(15, 6))

graph_title = '시계열'
ax.set_title(f'{graph_title}')
ax.set_xlabel('시간', labelpad=20)
ax.set_ylabel('가격', labelpad=20)

ax.plot([1, 2, 3], [50000, 51000, 52000])

plt.show()

# %%
# https://www.data.go.kr/data/3048950/fileData.do

# %%
import pandas as pd
import io

df = pd.read_csv('한국교통안전공단_자동차결함 리콜현황_20221231.csv', encoding='cp949')

# %%
df
# Out:
#                  제작자                        차명    생산기간(부터)    생산기간(까지)  \
# 0           혼다코리아(주)               CBR1000RR-R  2021-04-29  2021-05-12
# 1     폭스바겐그룹코리아 주식회사     Polo 5 FL 1.4 TDI BMT  2014-11-17  2014-11-25
# 2     폭스바겐그룹코리아 주식회사  Jetta 6 FL 2.0 TDI 110PS  2014-11-05  2015-02-26
# 3     폭스바겐그룹코리아 주식회사         Jetta 1.6 TDI BMT  2011-02-28  2012-09-25
# 4     폭스바겐그룹코리아 주식회사       Golf A7 1.6 TDI BMT  2014-12-19  2015-02-26
# ...              ...                       ...         ...         ...
# 1414     비엠더블유코리아(주)                BMW i4 M50  2021-11-22  2022-10-24
# 1415     비엠더블유코리아(주)           BMW i4 eDrive40  2021-11-23  2022-10-24
# 1416  (주)스포츠모터사이클코리아         1290 SUPER DUKE R  2020-02-11  2022-04-29
# 1417         화창상사(주)               SPRINGFIELD  2019-10-28  2020-06-03
# 1418         화창상사(주)             CHIEF VINTAGE  2019-08-02  2020-06-04
#
#            리콜개시일                                               리콜사유
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1419 entries, 0 to 1418
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   제작자       1419 non-null   object
#  1   차명        1419 non-null   object
#  2   생산기간(부터)  1419 non-null   object
#  3   생산기간(까지)  1419 non-null   object
#  4   리콜개시일     1419 non-null   object
#  5   리콜사유      1419 non-null   object
# dtypes: object(6)
# memory usage: 66.6+ KB

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# !pip install seaborn==0.9.0
import seaborn as sns
print(sns.__version__)
# Out:
# ...
# 0.9.0

# %%
df.head(10)
# Out:
#               제작자                        차명    생산기간(부터)    생산기간(까지)  \
# 0        혼다코리아(주)               CBR1000RR-R  2021-04-29  2021-05-12
# 1  폭스바겐그룹코리아 주식회사     Polo 5 FL 1.4 TDI BMT  2014-11-17  2014-11-25
# 2  폭스바겐그룹코리아 주식회사  Jetta 6 FL 2.0 TDI 110PS  2014-11-05  2015-02-26
# 3  폭스바겐그룹코리아 주식회사         Jetta 1.6 TDI BMT  2011-02-28  2012-09-25
# 4  폭스바겐그룹코리아 주식회사       Golf A7 1.6 TDI BMT  2014-12-19  2015-02-26
# 5  폭스바겐그룹코리아 주식회사          Golf 1.6 TDI BMT  2010-07-02  2012-10-01
# 6   메르세데스벤츠코리아(주)          GLC 220 d 4MATIC  2020-08-06  2020-08-06
# 7   메르세데스벤츠코리아(주)            E 220 d 4MATIC  2020-08-26  2020-08-26
# 8   메르세데스벤츠코리아(주)    GLE 350 e 4MATIC Coupe  2020-03-25  2021-01-26
# 9   메르세데스벤츠코리아(주)          GLE 350 e 4MATIC  2020-03-27  2021-01-25
#
#         리콜개시일                                               리콜사유
# 0  2022-01-03  제작 공정 중 라디에이터 캡의 제조 불량으로 라디에이터 캡과 필러넥이 제대로 밀착되...
# 1  2022-01-05  특정 기간 내에 특정 공급 업체(이드낙)의 생산 공정 불량으로 인해, 메카트로닉스 ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1419 entries, 0 to 1418
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   제작자       1419 non-null   object
#  1   차명        1419 non-null   object
#  2   생산기간(부터)  1419 non-null   object
#  3   생산기간(까지)  1419 non-null   object
#  4   리콜개시일     1419 non-null   object
#  5   리콜사유      1419 non-null   object
# dtypes: object(6)
# memory usage: 66.6+ KB

# %%
df.isna().sum()
# Out:
# 제작자         0
# 차명          0
# 생산기간(부터)    0
# 생산기간(까지)    0
# 리콜개시일       0
# 리콜사유        0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#                 제작자              차명    생산기간(부터)    생산기간(까지)       리콜개시일  \
# 304       대전기계공업(주)            W800  2019-02-21  2022-02-10  2022-03-28
# 393   메르세데스벤츠코리아(주)           A 220  2021-09-16  2021-09-16  2022-04-08
# 528   (주)재규어랜드로버코리아  레인지로버 이보크 2.0D  2015-05-14  2017-07-27  2022-05-02
# 1145   스카니아코리아그룹(주)          스카니아카고  2021-02-15  2021-02-16  2022-10-11
# 1217  (주)재규어랜드로버코리아  레인지로버 이보크 2.0D  2015-05-14  2017-07-27  2022-11-01
#
#                                                    리콜사유
# 304   경음기에 전기 배선을 연결하는 단자의 내구성 부족으로 주행 중 특정한 엔진 회전 영...
# 393   비상 통신 시스템(eCall)을 위한 통신 모듈 소프트웨어가 사양에 맞지 않아 차량...
# 528   엔진오일오염도 증가에 따른 엔진오일펌프, 타이밍체인의 마모 및 파손 엔진오일 서비스...
# 1145         타이로드 끝 부분에 슬롯이 없는 타이로드가 장착되어 있을 가능성이 있습니다.
# 1217  엔진오일오염도 증가에 따른 엔진오일펌프, 타이밍체인의 마모 및 파손 엔진오일 서비스...

# %%
df[df.duplicated(keep=False)]
# Out:
#                 제작자              차명    생산기간(부터)    생산기간(까지)       리콜개시일  \
# 303       대전기계공업(주)            W800  2019-02-21  2022-02-10  2022-03-28
# 304       대전기계공업(주)            W800  2019-02-21  2022-02-10  2022-03-28
# 392   메르세데스벤츠코리아(주)           A 220  2021-09-16  2021-09-16  2022-04-08
# 393   메르세데스벤츠코리아(주)           A 220  2021-09-16  2021-09-16  2022-04-08
# 527   (주)재규어랜드로버코리아  레인지로버 이보크 2.0D  2015-05-14  2017-07-27  2022-05-02
# 528   (주)재규어랜드로버코리아  레인지로버 이보크 2.0D  2015-05-14  2017-07-27  2022-05-02
# 1144   스카니아코리아그룹(주)          스카니아카고  2021-02-15  2021-02-16  2022-10-11
# 1145   스카니아코리아그룹(주)          스카니아카고  2021-02-15  2021-02-16  2022-10-11
# 1216  (주)재규어랜드로버코리아  레인지로버 이보크 2.0D  2015-05-14  2017-07-27  2022-11-01
# 1217  (주)재규어랜드로버코리아  레인지로버 이보크 2.0D  2015-05-14  2017-07-27  2022-11-01
#
#                                                    리콜사유
# 303   경음기에 전기 배선을 연결하는 단자의 내구성 부족으로 주행 중 특정한 엔진 회전 영...
# 304   경음기에 전기 배선을 연결하는 단자의 내구성 부족으로 주행 중 특정한 엔진 회전 영...
# ...

# %%
df.columns
# Out:
# Index(['제작자', '차명', '생산기간(부터)', '생산기간(까지)', '리콜개시일', '리콜사유'], dtype='object')

# %%
print("Before:", len(df))
df = df.drop_duplicates()
print("After:", len(df))
# Out:
# Before: 1419
# After: 1414

# %%
df.iloc[0]
# Out:
# 제작자                                                  혼다코리아(주)
# 차명                                                CBR1000RR-R
# 생산기간(부터)                                           2021-04-29
# 생산기간(까지)                                           2021-05-12
# 리콜개시일                                              2022-01-03
# 리콜사유        제작 공정 중 라디에이터 캡의 제조 불량으로 라디에이터 캡과 필러넥이 제대로 밀착되...
# Name: 0, dtype: object

# %%
def parse_year(s):
    return int(s[:4])
def parse_month(s):
    return int(s[5:7])
def parse_day(s):
    return int(s[8:])

# Pandas DataFrame에서는 row별로 loop를 도는 것이 굉장히 느리기 때문에, apply() 함수를 이용하여 벡터 연산을 진행합니다.
df['start_year'] = df['생산기간(부터)'].apply(parse_year)
df['start_month'] = df['생산기간(부터)'].apply(parse_month)
df['start_day'] = df['생산기간(부터)'].apply(parse_day)

df['end_year'] = df['생산기간(까지)'].apply(parse_year)
df['end_month'] = df['생산기간(까지)'].apply(parse_month)
df['end_day'] = df['생산기간(까지)'].apply(parse_day)

df['recall_year'] = df['리콜개시일'].apply(parse_year)
df['recall_month'] = df['리콜개시일'].apply(parse_month)
df['recall_day'] = df['리콜개시일'].apply(parse_day)
# Out:
# <ipython-input-15-a4981f64322c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_year'] = df['생산기간(부터)'].apply(parse_year)
# <ipython-input-15-a4981f64322c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_month'] = df['생산기간(부터)'].apply(parse_month)
# <ipython-input-15-a4981f64322c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df.head(10)
# Out:
#               제작자                        차명    생산기간(부터)    생산기간(까지)  \
# 0        혼다코리아(주)               CBR1000RR-R  2021-04-29  2021-05-12
# 1  폭스바겐그룹코리아 주식회사     Polo 5 FL 1.4 TDI BMT  2014-11-17  2014-11-25
# 2  폭스바겐그룹코리아 주식회사  Jetta 6 FL 2.0 TDI 110PS  2014-11-05  2015-02-26
# 3  폭스바겐그룹코리아 주식회사         Jetta 1.6 TDI BMT  2011-02-28  2012-09-25
# 4  폭스바겐그룹코리아 주식회사       Golf A7 1.6 TDI BMT  2014-12-19  2015-02-26
# 5  폭스바겐그룹코리아 주식회사          Golf 1.6 TDI BMT  2010-07-02  2012-10-01
# 6   메르세데스벤츠코리아(주)          GLC 220 d 4MATIC  2020-08-06  2020-08-06
# 7   메르세데스벤츠코리아(주)            E 220 d 4MATIC  2020-08-26  2020-08-26
# 8   메르세데스벤츠코리아(주)    GLE 350 e 4MATIC Coupe  2020-03-25  2021-01-26
# 9   메르세데스벤츠코리아(주)          GLE 350 e 4MATIC  2020-03-27  2021-01-25
#
#         리콜개시일                                               리콜사유  start_year  \
# 0  2022-01-03  제작 공정 중 라디에이터 캡의 제조 불량으로 라디에이터 캡과 필러넥이 제대로 밀착되...        2021
# ...

# %%
df.columns
# Out:
# Index(['제작자', '차명', '생산기간(부터)', '생산기간(까지)', '리콜개시일', '리콜사유', 'start_year',
#        'start_month', 'start_day', 'end_year', 'end_month', 'end_day',
#        'recall_year', 'recall_month', 'recall_day'],
#       dtype='object')

# %%
from collections import Counter

Counter(df['recall_year'])
# Out:
# Counter({2022: 1414})

# %%
df.recall_year.min(), df.recall_year.max()

# 2022년 데이터만 분석
df = df[df['recall_year']==2022]
len(df)
# Out:
# 1414

# %%
Counter(df['제작자']).most_common()
# Out:
# [('비엠더블유코리아(주)', 432),
#  ('메르세데스벤츠코리아(주)', 329),
#  ('폭스바겐그룹코리아 주식회사', 216),
#  ('현대자동차(주)', 61),
#  ('만트럭버스코리아(주)', 41),
#  ('기아주식회사', 38),
#  ('포드세일즈서비스코리아(유)', 37),
#  ('스텔란티스코리아주식회사', 31),
#  ('(주)에프엠케이', 31),
#  ('(주)재규어랜드로버코리아', 24),
#  ('(유)기흥모터스', 21),
#  ('포르쉐코리아 주식회사', 20),
#  ('테슬라코리아 유한회사', 20),
#  ('화창상사(주)', 16),
#  ('혼다코리아(주)', 15),
#  ('(주)볼보자동차코리아', 13),
#  ('다임러트럭코리아(주)', 9),
#  ('스카니아코리아그룹(주)', 9),
#  ('르노코리아자동차 주식회사', 7),
#  ('(주)피라인', 5),
#  ('한국토요타자동차(주)', 5),
#  ('범한자동차 주식회사', 4),
#  ('볼보트럭코리아(주)', 4),
#  ('지엠코리아(주)', 4),
#  ('(주) 한국모터트레이딩', 3),
#  ('(주) 바이크코리아', 3),
#  ('대전기계공업(주)', 3),
#  ('한국지엠(주)', 3),
#  ('(주)다산중공업', 2),
#  ('모토스타코리아(주)', 2),
#  ('주식회사 마이브', 1),
#  ('기흥인터내셔널 유한회사', 1),
#  ('폴스타오토모티브코리아 유한회사', 1),
#  ('유한회사 모토로싸', 1),
#  ('한신특장', 1),
#  ('(주)스포츠모터사이클코리아', 1)]

# %%
df.groupby("제작자")["차명"].count()
# Out:
# 제작자
# (유)기흥모터스             21
# (주) 바이크코리아            3
# (주) 한국모터트레이딩          3
# (주)다산중공업              2
# (주)볼보자동차코리아          13
# (주)스포츠모터사이클코리아        1
# (주)에프엠케이             31
# (주)재규어랜드로버코리아        24
# (주)피라인                5
# 기아주식회사               38
# 기흥인터내셔널 유한회사          1
# 다임러트럭코리아(주)           9
# 대전기계공업(주)             3
# 르노코리아자동차 주식회사         7
# 만트럭버스코리아(주)          41
# 메르세데스벤츠코리아(주)       329
# 모토스타코리아(주)            2
# 범한자동차 주식회사            4
# 볼보트럭코리아(주)            4
# 비엠더블유코리아(주)         432
# 스카니아코리아그룹(주)          9
# 스텔란티스코리아주식회사         31
# 유한회사 모토로싸             1
# 주식회사 마이브              1
# 지엠코리아(주)              4
# 테슬라코리아 유한회사          20
# 포드세일즈서비스코리아(유)       37
# 포르쉐코리아 주식회사          20
# 폭스바겐그룹코리아 주식회사      216
# 폴스타오토모티브코리아 유한회사      1
# 한국지엠(주)               3
# 한국토요타자동차(주)           5
# 한신특장                  1
# 현대자동차(주)             61
# 혼다코리아(주)             15
# 화창상사(주)              16
# Name: 차명, dtype: int64

# %%
df.groupby("제작자")["차명"].count().sort_values(ascending=False)
# Out:
# 제작자
# 비엠더블유코리아(주)         432
# 메르세데스벤츠코리아(주)       329
# 폭스바겐그룹코리아 주식회사      216
# 현대자동차(주)             61
# 만트럭버스코리아(주)          41
# 기아주식회사               38
# 포드세일즈서비스코리아(유)       37
# (주)에프엠케이             31
# 스텔란티스코리아주식회사         31
# (주)재규어랜드로버코리아        24
# (유)기흥모터스             21
# 포르쉐코리아 주식회사          20
# 테슬라코리아 유한회사          20
# 화창상사(주)              16
# 혼다코리아(주)             15
# (주)볼보자동차코리아          13
# 스카니아코리아그룹(주)          9
# 다임러트럭코리아(주)           9
# 르노코리아자동차 주식회사         7
# 한국토요타자동차(주)           5
# (주)피라인                5
# 지엠코리아(주)              4
# 범한자동차 주식회사            4
# 볼보트럭코리아(주)            4
# 대전기계공업(주)             3
# (주) 바이크코리아            3
# 한국지엠(주)               3
# (주) 한국모터트레이딩          3
# (주)다산중공업              2
# 모토스타코리아(주)            2
# 기흥인터내셔널 유한회사          1
# 유한회사 모토로싸             1
# 주식회사 마이브              1
# (주)스포츠모터사이클코리아        1
# 폴스타오토모티브코리아 유한회사      1
# 한신특장                  1
# Name: 차명, dtype: int64

# %%
df.groupby("제작자")["차명"].count()

# %%
df.groupby("제작자")["차명"].count().sort_values(ascending=False))

# %%
pd.DataFrame(df.groupby("제작자")["차명"].count().sort_values(ascending=False)))

# %%
pd.DataFrame(df.groupby("제작자")["차명"].count().sort_values(ascending=False)).rename(columns={"차명": "count"})
# Out:
#                   count
# 제작자
# 비엠더블유코리아(주)         432
# 메르세데스벤츠코리아(주)       329
# 폭스바겐그룹코리아 주식회사      216
# 현대자동차(주)             61
# 만트럭버스코리아(주)          41
# 기아주식회사               38
# 포드세일즈서비스코리아(유)       37
# (주)에프엠케이             31
# 스텔란티스코리아주식회사         31
# (주)재규어랜드로버코리아        24
# (유)기흥모터스             21
# 포르쉐코리아 주식회사          20
# 테슬라코리아 유한회사          20
# 화창상사(주)              16
# 혼다코리아(주)             15
# (주)볼보자동차코리아          13
# 스카니아코리아그룹(주)          9
# 다임러트럭코리아(주)           9
# 르노코리아자동차 주식회사         7
# 한국토요타자동차(주)           5
# (주)피라인                5
# 지엠코리아(주)              4
# 범한자동차 주식회사            4
# 볼보트럭코리아(주)            4
# 대전기계공업(주)             3
# (주) 바이크코리아            3
# 한국지엠(주)               3
# (주) 한국모터트레이딩          3
# (주)다산중공업              2
# 모토스타코리아(주)            2
# 기흥인터내셔널 유한회사          1
# 유한회사 모토로싸             1
# 주식회사 마이브              1
# (주)스포츠모터사이클코리아        1
# 폴스타오토모티브코리아 유한회사      1
# 한신특장                  1

# %%
df['제작자'].value_counts()
# Out:
# 제작자
# 비엠더블유코리아(주)         432
# 메르세데스벤츠코리아(주)       329
# 폭스바겐그룹코리아 주식회사      216
# 현대자동차(주)             61
# 만트럭버스코리아(주)          41
# 기아주식회사               38
# 포드세일즈서비스코리아(유)       37
# (주)에프엠케이             31
# 스텔란티스코리아주식회사         31
# (주)재규어랜드로버코리아        24
# (유)기흥모터스             21
# 테슬라코리아 유한회사          20
# 포르쉐코리아 주식회사          20
# 화창상사(주)              16
# 혼다코리아(주)             15
# (주)볼보자동차코리아          13
# 스카니아코리아그룹(주)          9
# 다임러트럭코리아(주)           9
# 르노코리아자동차 주식회사         7
# (주)피라인                5
# 한국토요타자동차(주)           5
# 지엠코리아(주)              4
# 범한자동차 주식회사            4
# 볼보트럭코리아(주)            4
# 한국지엠(주)               3
# 대전기계공업(주)             3
# (주) 바이크코리아            3
# (주) 한국모터트레이딩          3
# (주)다산중공업              2
# 모토스타코리아(주)            2
# 기흥인터내셔널 유한회사          1
# 폴스타오토모티브코리아 유한회사      1
# 주식회사 마이브              1
# 유한회사 모토로싸             1
# 한신특장                  1
# (주)스포츠모터사이클코리아        1
# Name: count, dtype: int64

# %%
tmp = pd.DataFrame(df.groupby("제작자").count()["차명"].sort_values(ascending=False)).rename(columns={"차명": "count"})

plt.figure(figsize=(20,10))
# 한글 출력을 위해서 폰트 옵션을 설정합니다.
sns.set(font="NanumGothic",
        rc={"axes.unicode_minus":False},
        style='darkgrid')
ax = sns.countplot(x="제작자", data=df, palette="Set2", order=tmp.index)
plt.xticks(rotation=270)
plt.show()

# %%
df['차명'].value_counts()
# Out:
# 차명
# 328i                                        25
# TGX                                         22
# TGS                                         18
# C 300                                       13
# 328xi                                       11
#                                             ..
# Citroen C3 Aircross 1.5 BlueHDi              1
# Citroen C4 Cactus 1.5 BlueHDi(EAT6)          1
# Citroen Grand C4 Spacetourer 1.5 BlueHDi     1
# DS3 Crossback 1.5 BlueHDi                    1
# 1290 SUPER DUKE R                            1
# Name: count, Length: 728, dtype: int64

# %%
grouped = df.groupby('제작자')['차명'].apply(lambda x: list(x.unique())).to_frame()
grouped['num'] = grouped['차명'].apply(len)
grouped.sort_values(by='num', ascending=False)
# Out:
#                                                                  차명  num
# 제작자
# 비엠더블유코리아(주)       [BMW i4 M50, BMW i4 eDrive40, Rolls-Royce Ghos...  182
# 메르세데스벤츠코리아(주)     [GLC 220 d 4MATIC, E 220 d 4MATIC, GLE 350 e 4...  142
# 폭스바겐그룹코리아 주식회사    [Polo 5 FL 1.4 TDI BMT, Jetta 6 FL 2.0 TDI 110...  105
# 현대자동차(주)          [싼타페 하이브리드 (TM PE HEV), 싼타페 (TM PE), 쏘나타 하이브리드...   47
# 포드세일즈서비스코리아(유)    [2011-2013년식 Explorer, 2021년식 Mustang, 2013-20...   30
# (주)에프엠케이          [페라리 488 Spider, 페라리 488 GTB, 페라리 458 Speciale...   30
# 기아주식회사            [레이(TAMPE), K3(YDPE), 쏘울EV(PSEV), 쏘울(PS), 카니발(...   28
# 스텔란티스코리아주식회사      [500X, 200, 짚컴패스, 짚체로키, 짚레니게이드, DS3 Crossback ...   25
# (유)기흥모터스          [RA1250S, RA1250, HARLEY-DAVIDSON RH1250S, HAR...   21
# (주)재규어랜드로버코리아     [디스커버리 SD4, 레인지로버 이보크 2.0D, 디스커버리 스포츠 2.0D, 더 ...   21
# 혼다코리아(주)          [CBR1000RR-R, PILOT, CR-V HEV, CR-V, ACCORD HE...   12
# 화창상사(주)           [CHIEFTAIN, CHIEF VINTAGE, CHIEF CLASSIC, SPRI...   11
# ...

# %%
tmp = pd.DataFrame(df.groupby("차명").count()["제작자"].sort_values(ascending=False))
tmp = tmp.rename(columns={"제작자": "count"}).iloc[:50]

# %%
plt.figure(figsize=(10,5))

# seaborn의 countplot 함수를 사용하여 출력합니다.
sns.set(font="NanumGothic",
        rc={"axes.unicode_minus":False},
        style='darkgrid')
ax = sns.countplot(x="차명", data=df[df['차명'].isin(tmp.index)], palette="Set2", order=tmp.index)
plt.xticks(rotation=270)
plt.show()

# %%
pd.DataFrame(df.groupby("recall_month").count()["start_year"].sort_values(ascending=False)).rename(columns={"start_year": "count"})
# Out:
#               count
# recall_month
# 2               177
# 4               171
# 6               152
# 8               138
# 12              138
# 10              135
# 3               122
# 5                90
# 9                87
# 7                85
# 11               64
# 1                55

# %%
tmp = pd.DataFrame(df.groupby("start_year")["차명"].count()).rename(columns={"차명": "count"}).reset_index()

plt.plot(tmp['start_year'], tmp['count'])
plt.show()

# %%
sorted(set(df['제작자']))
# Out:
# ['(유)기흥모터스',
#  '(주) 바이크코리아',
#  '(주) 한국모터트레이딩',
#  '(주)다산중공업',
#  '(주)볼보자동차코리아',
#  '(주)스포츠모터사이클코리아',
#  '(주)에프엠케이',
#  '(주)재규어랜드로버코리아',
#  '(주)피라인',
#  '기아주식회사',
#  '기흥인터내셔널 유한회사',
#  '다임러트럭코리아(주)',
#  '대전기계공업(주)',
#  '르노코리아자동차 주식회사',
#  '만트럭버스코리아(주)',
#  '메르세데스벤츠코리아(주)',
#  '모토스타코리아(주)',
#  '범한자동차 주식회사',
#  '볼보트럭코리아(주)',
#  '비엠더블유코리아(주)',
#  '스카니아코리아그룹(주)',
#  '스텔란티스코리아주식회사',
#  '유한회사 모토로싸',
#  '주식회사 마이브',
#  '지엠코리아(주)',
#  '테슬라코리아 유한회사',
#  '포드세일즈서비스코리아(유)',
#  '포르쉐코리아 주식회사',
#  '폭스바겐그룹코리아 주식회사',
#  '폴스타오토모티브코리아 유한회사',
#  '한국지엠(주)',
#  '한국토요타자동차(주)',
#  '한신특장',
#  '현대자동차(주)',
#  '혼다코리아(주)',
#  '화창상사(주)']

# %%
df[df['제작자'].isin(['현대자동차(주)', '기아주식회사'])]['차명'].value_counts()
# Out:
# 차명
# 싼타페(TM PE)           3
# 넥쏘(FE)               3
# 카니발(KA4)             3
# 싼타페 하이브리드(TM HEV)    3
# 쏘렌토(MQ4)             3
#                     ..
# 유니버스(PY)             1
# 그랜버드(GZ)             1
# 더 뉴 팰리세이드            1
# 일렉시티 수소전기버스(CY)      1
# 카운티 일렉트릭(MF)         1
# Name: count, Length: 75, dtype: int64

# %%
df[df['제작자'] == '비엠더블유코리아(주)']['차명'].value_counts()
# Out:
# 차명
# 328i                                 25
# 328xi                                11
# 520d                                  8
# 520d xDrive                           7
# BMW X3 xDrive20d M Sport Package      6
#                                      ..
# 630d xDrive                           1
# 840d xDrive Gran Coupe Excellence     1
# X3 xDrive30d M Sport Package          1
# X4 M40d                               1
# BMW iX3 M Sport                       1
# Name: count, Length: 182, dtype: int64

# %%
df[df.recall_month.isin([10,11,12])].head()
# Out:
#            제작자             차명    생산기간(부터)    생산기간(까지)       리콜개시일  \
# 1080  (주)에프엠케이        페라리Roma  2020-01-01  2022-06-30  2022-10-04
# 1081  (주)에프엠케이    페라리F8Spider  2020-01-01  2022-06-30  2022-10-04
# 1082  (주)에프엠케이   페라리F8Tributo  2019-01-01  2022-06-30  2022-10-04
# 1083  (주)에프엠케이  페라리PortofinoM  2021-01-01  2022-06-30  2022-10-04
# 1084  (주)에프엠케이   페라리Portofino  2018-01-01  2020-12-31  2022-10-04
#
#                                                    리콜사유  start_year  \
# 1080  브레이크 오일 리저버 탱크 캡에서 대기압을 유지하기 위한 공기통로의 불량으로 브레이...        2020
# 1081  브레이크 오일 리저버 탱크 캡에서 대기압을 유지하기 위한 공기통로의 불량으로 브레이...        2020
# 1082  브레이크 오일 리저버 탱크 캡에서 대기압을 유지하기 위한 공기통로의 불량으로 브레이...        2019
# 1083  브레이크 오일 리저버 탱크 캡에서 대기압을 유지하기 위한 공기통로의 불량으로 브레이...        2021
# 1084  브레이크 오일 리저버 탱크 캡에서 대기압을 유지하기 위한 공기통로의 불량으로 브레이...        2018
#
#       start_month  start_day  end_year  end_month  end_day  recall_year  \
# 1080            1          1      2022          6       30         2022
# ...

# %%
df[df.recall_month.isin([10,11,12])].columns
# Out:
# Index(['제작자', '차명', '생산기간(부터)', '생산기간(까지)', '리콜개시일', '리콜사유', 'start_year',
#        'start_month', 'start_day', 'end_year', 'end_month', 'end_day',
#        'recall_year', 'recall_month', 'recall_day'],
#       dtype='object')

# %%
# !pip install numpy==1.19.5
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 46.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for numpy (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for numpy
# Failed to build numpy
# ERROR: Could not build wheels for numpy, which is required to install pyproject.toml-based projects

# %%
df[df.recall_month.isin([10,11,12])]['차명']
# Out:
# 1080              페라리Roma
# 1081          페라리F8Spider
# 1082         페라리F8Tributo
# 1083        페라리PortofinoM
# 1084         페라리Portofino
#               ...
# 1414           BMW i4 M50
# 1415      BMW i4 eDrive40
# 1416    1290 SUPER DUKE R
# 1417          SPRINGFIELD
# 1418        CHIEF VINTAGE
# Name: 차명, Length: 337, dtype: object

# %%
plt.figure(figsize=(20,10))
ax.hist(df[df.recall_month.isin([10,11,12])]['차명'])
plt.xticks(rotation=270)
plt.show()

# %%
# 워드 클라우드 생성을 도와주는 패키지를 가져옵니다.
try:
    from wordcloud import WordCloud, STOPWORDS
except:
    # !pip install wordcloud
    from wordcloud import WordCloud, STOPWORDS

# %%
set(STOPWORDS)
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
# ...

# %%
df['리콜사유'].iloc[0]
# Out:
# '제작 공정 중 라디에이터 캡의 제조 불량으로 라디에이터 캡과 필러넥이 제대로 밀착되지 않아 라디에이터 내부 압력을 일정하게 유지할 수 없습니다. 이로 인해 라디에이터 내부 압력이 높아지면 냉각수 저장 탱크의 오버플로 튜브에서 냉각수가 분출될 수 있습니다.'

# %%
spwords = set(["동안", "인하여", "있는", "경우", "있습니다", "가능성이", "않을", "차량의", "가", "에", "될", "이",
               "인해", "수", "중", "시", "또는", "있음", "의", "및", "있으며", "발생할", "이로", "오류로", "해당", "제대로", "않아"])


#
text = ""

for c in df['리콜사유'].drop_duplicates():
    text += c

text[:100]
# Out:
# '제작 공정 중 라디에이터 캡의 제조 불량으로 라디에이터 캡과 필러넥이 제대로 밀착되지 않아 라디에이터 내부 압력을 일정하게 유지할 수 없습니다. 이로 인해 라디에이터 내부 압력이 '

# %%
len(text)
# Out:
# 34826

# %%
wc1 = WordCloud(max_font_size=200, stopwords=spwords, font_path='/usr/share/fonts/truetype/nanum/NanumGothic.ttf',
                background_color='white', width=800, height=800)
wc1.generate(text)

plt.figure(figsize=(10, 8))
plt.imshow(wc1)
plt.tight_layout(pad=0)
plt.axis('off')
plt.show()

# %%
df_hyundai = df[df['제작자'] == '현대자동차(주)']
df_bmw = df[df['제작자'] == '비엠더블유코리아(주)']

text_hyundai = ""
text_bmw = ""

for c in df_hyundai['리콜사유'].drop_duplicates():
    text_hyundai += c

for c in df_bmw['리콜사유'].drop_duplicates():
    text_bmw += c

# %%
wc_hyundai = WordCloud(max_font_size=200, stopwords=spwords, font_path='/usr/share/fonts/truetype/nanum/NanumGothic.ttf',
                background_color='white', width=800, height=800)
wc_hyundai.generate(text_hyundai)

wc_bmw = WordCloud(max_font_size=200, stopwords=spwords, font_path='/usr/share/fonts/truetype/nanum/NanumGothic.ttf',
                background_color='white', width=800, height=800)
wc_bmw.generate(text_hyundai)

fig, ax = plt.subplots(1, 2, figsize=(20, 8))
ax[0].imshow(wc_hyundai)
ax[1].imshow(wc_bmw)

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 8))
ax[0].imshow(wc_hyundai)
ax[1].imshow(wc_bmw)

ax[0].set_title('현대자동차', fontsize=20)
ax[1].set_title('BMW', fontsize=20)


plt.tight_layout(pad=0)
plt.axis('off')
plt.show()
